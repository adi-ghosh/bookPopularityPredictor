# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# filepath_dict = {'A_Tree_Grows_In_Brooklyn.txt':   ('BoW/A_Tree_Grows_In_Brooklyn_BoW.txt', 1),
#                  'Atlas_Shrugged.txt': ('BoW/Atlas_Shrugged_BoW.txt', 3),
#                  'Huckleberry_Finn.txt':   ('BoW/Huckleberry_Finn_BoW.txt', 2),
#                  'The_Awakening.txt': ('BoW/The_Awakening_BoW.txt', 4)}


# text_BoW_files = ['BoW/A_Tree_Grows_In_Brooklyn_BoW.txt', 'BoW/Atlas_Shrugged_BoW.txt', 
#               'BoW/Huckleberry_Finn_BoW.txt', 'BoW/The_Awakening_BoW.txt']

# # text_files = ['data/A_Tree_Grows_In_Brooklyn.txt', 'data/Atlas_Shrugged.txt', 
# #               'data/Huckleberry_Finn.txt', 'data/The_Awakening.txt']
# text_files = ['data/test1.txt', 'data/test2.txt', 'data/test3.txt', 'data/test4.txt']

rank = [4.33, 4.17, 4.01, 3.99, 4.04, 3.84, 4.03, 3.54, 4.13, 3.62, 3.68, 3.92, 3.75, 3.66, 3.83]

# %%
# opening the file in read mode
my_file = open("data_list.txt", "r")

# reading the file
path_data = my_file.read()

# replacing end splitting the text
# when newline ('\n') is seen.
paths = path_data.split("\n")
print(paths)
my_file.close()
# Out:
# ['FullTexts/A_Tree_Grows_In_Brooklyn.txt', 'FullTexts/Atlas_Shrugged.txt', 'FullTexts/Collected_Poems_Emily_Dickinson.txt', 'FullTexts/Farenheit_451.txt', 'FullTexts/Grapes_of_Wrath.txt', 'FullTexts/Huckleberry_Finn.txt', 'FullTexts/Incidents_in_The_Life_of_a_Slave_Girl.txt', 'FullTexts/Maggie_A_Girl_of_The_Streets.txt', 'FullTexts/Slaughterhouse-five.txt', 'FullTexts/The_Awakening.txt', 'FullTexts/The_Cruicble.txt', 'FullTexts/The_House_of_Mirth.txt', 'FullTexts/The_Jungle.txt', 'FullTexts/The_Portrait_of_a_Lady.txt', 'FullTexts/Walden.txt']

# %%
contents = []
# paths = ['data/A_Tree_Grows_In_Brooklyn.txt', 'data/Atlas_Shrugged.txt', 'data/Huckleberry_Finn.txt', 'data/The_Awakening.txt']
# paths = ['data/test1.txt', 'data/test2.txt', 'data/test3.txt', 'data/test4.txt']

for path in paths:
    with open(path, 'r', encoding='utf-8') as f:     # encoding='utf-8'不行
        for line in f.readlines():
            contents.append(line)
    f.close()
    
data = pd.DataFrame([])
data["text"] = contents
data["label"] = rank
data
# Out:
#                                                  text  label
# 0   ﻿A Tree Grows in Brooklyn Betty Smith A Tree G...   4.33
# 1   ﻿CONTENTS PART I NON- CONTRAD ICT ION I THE TH...   4.17
# 2   ﻿This is my letter to the world,    That never...   4.01
# 3   ﻿oneThe Hearth and the SalamanderIt was a plea...   3.99
# 4   ﻿THE MODERN LIBRARY OF THE WORLD’S BEST BOOKS ...   4.04
# 5   ﻿The Project Gutenberg eBook of The Adventures...   3.84
# 6   ﻿I. ChildhoodI was born a slave; but I never k...   4.03
# 7   ﻿Chapter IA very little boy stood upon a heap ...   3.54
# 8   ﻿OneAll this happened, more or less. The war p...   4.13
# 9   ﻿THE AWAKENINGIA green and yellow parrot, whic...   3.62
# 10  ﻿The Crucible Arthur MillerA NOTE ON THE HISTO...   3.68
# 11  ﻿Selden paused in surprise. In the afternoon r...   3.92
# 12  ﻿CHAPTER IIt was four o’clock when the ceremon...   3.75
# 13  ﻿THE PORTRAIT OF A LADYCHAPTER IUnder certain ...   3.66
# 14  ﻿WALDENEconomyWhen I wrote the following pages...   3.83

# %%
data.label.unique()
# Out:
# array([4.33, 4.17, 4.01, 3.99, 4.04, 3.84, 4.03, 3.54, 4.13, 3.62, 3.68,
#        3.92, 3.75, 3.66, 3.83])

# %%
import re
token = re.compile('[A-Za-z]+|[!?,.()]')

# %%
def reg_text(text):
    new_text = token.findall(text)
    new_text = [word.lower() for word in new_text]
    return new_text

# %%
data['text'] = data.text.apply(reg_text)

# %%
word_set = set()
for text in data.text:
    for word in text:
        word_set.add(word) 
max_word = len(word_set) + 1
max_word
# Out:
# 45137

# %%
word_list = list(word_set)
word_list.index('school')
# Out:
# 1817

# %%
word_index =  dict((word, word_list.index(word) + 1) for word in word_list)
word_index
# Out:
# {'invade': 1,
#  'reasonable': 2,
#  'peremptory': 3,
#  'pondssometimes': 4,
#  'oleariam': 5,
#  'bejuggled': 6,
#  'dislike': 7,
#  'veterans': 8,
#  'reposed': 9,
#  'plead': 10,
#  'panion': 11,
#  'tation': 12,
#  'haines': 13,
#  'starkest': 14,
#  'recuperate': 15,
#  'cute': 16,
#  'slowed': 17,
#  'seeds': 18,
#  'asrich': 19,
#  'problemin': 20,
#  'fortaking': 21,
#  'camein': 22,
#  'dragon': 23,
#  'procaine': 24,
#  'vats': 25,
#  'jelly': 26,
#  'awalk': 27,
#  'renownthat': 28,
#  'atmontag': 29,
#  'solemnly': 30,
#  'swiftcurrent': 31,
#  'discoverable': 32,
#  'incurring': 33,
#  'demonstrated': 34,
#  'shove': 35,
#  'levipes': 36,
#  'pictorial': 37,
#  'denser': 38,
#  'imperturbability': 39,
#  'foremost': 40,
#  'hindering': 41,
#  'ortoo': 42,
#  'yair': 43,
#  'rosashara': 44,
#  'thatfirst': 45,
#  'unfocusing': 46,
#  'tenants': 47,
#  'accepts': 48,
#  'grossly': 49,
#  'suspect': 50,
#  'greedily': 51,
#  'topsfield': 52,
#  'whitened': 53,
#  'bestfriends': 54,
#  'hurry': 55,
#  'poised': 56,
#  'catch': 57,
#  'levy': 58,
#  'volition': 59,
#  'sublimity': 60,
#  'jittered': 61,
#  'complications': 62,
#  'keeper': 63,
#  'undeserved': 64,
#  'convent': 65,
#  'windbreak': 66,
#  'whothey': 67,
#  'awind': 68,
#  'gurgled': 69,
#  'drilled': 70,
#  'coordinator': 71,
#  'beblamed': 72,
#  'consolation': 73,
#  'battling': 74,
#  'jailbird': 75,
#  'horridly': 76,
#  'longerthan': 77,
#  'mayflower': 78,
#  'washrooms': 79,
#  'baron': 80,
#  'atangle': 81,
#  'mistletoe': 82,
#  'somet': 83,
#  'mysterious': 84,
#  'corkscrew': 85,
#  'sworn': 86,
#  'downat': 87,
#  'dungeon': 88,
#  'penury': 89,
#  'foist': 90,
#  'attain': 91,
#  'posthumous': 92,
#  'gained': 93,
#  'denote': 94,
#  'snares': 95,
#  'beeches': 96,
#  'rip': 97,
#  'hustlingaway': 98,
#  'frankness': 99,
#  'alongthere': 100,
#  'spain': 101,
#  'smugly': 102,
#  'ruining': 103,
#  'oy': 104,
#  'gettingso': 105,
#  'smoked': 106,
#  'hewill': 107,
#  'utter': 108,
#  'muchthis': 109,
#  'caterpillars': 110,
#  'rediscovery': 111,
#  'immolated': 112,
#  'youm': 113,
#  'inmates': 114,
#  'richest': 115,
#  'leads': 116,
#  'tightness': 117,
#  'gainfully': 118,
#  'censor': 119,
#  'filmsonce': 120,
#  'chanced': 121,
#  'react': 122,
#  'passions': 123,
#  'girli': 124,
#  'uncertainly': 125,
#  'hension': 126,
#  'robins': 127,
#  'gruesome': 128,
#  'rowboat': 129,
#  'bold': 130,
#  'posing': 131,
#  'gainst': 132,
#  'fetchjim': 133,
#  'northern': 134,
#  'scuttling': 135,
#  'premise': 136,
#  'tinking': 137,
#  'pave': 138,
#  'handiest': 139,
#  'prizefighter': 140,
#  'theparrots': 141,
#  'midnightthat': 142,
#  'powerhouse': 143,
#  'indefinitely': 144,
#  'rining': 145,
#  'outlying': 146,
#  'agonizing': 147,
#  'outacross': 148,
#  'thetruth': 149,
#  'cuffy': 150,
#  'throned': 151,
#  'heliograph': 152,
#  'loudeston': 153,
#  'innew': 154,
#  'changesof': 155,
#  'regale': 156,
#  'suppositions': 157,
#  'ungained': 158,
#  'sailsmy': 159,
#  'strivin': 160,
#  'newly': 161,
#  'wiz': 162,
#  'swing': 163,
#  'refuted': 164,
#  'overrate': 165,
#  'avoided': 166,
#  'diseasedagain': 167,
#  'constitutional': 168,
#  'imposing': 169,
#  'genus': 170,
#  'sprays': 171,
#  'careless': 172,
#  'equalize': 173,
#  'automobile': 174,
#  'worp': 175,
#  'revery': 176,
#  'iliumschool': 177,
#  'becausepap': 178,
#  'pampa': 179,
#  'gollender': 180,
#  'modernizing': 181,
#  'powers': 182,
#  'ofmelted': 183,
#  'sidelights': 184,
#  'regrets': 185,
#  'endeavors': 186,
#  'fatalistic': 187,
#  'ransom': 188,
#  'generating': 189,
#  'intrusive': 190,
#  'rocking': 191,
#  'undertrained': 192,
#  'whereas': 193,
#  'smears': 194,
#  'wifestand': 195,
#  'wrongs': 196,
#  'tasting': 197,
#  'anchorage': 198,
#  'sloppily': 199,
#  'boners': 200,
#  'symmes': 201,
#  'decay': 202,
#  'zat': 203,
#  'allyou': 204,
#  'onstage': 205,
#  'theysmell': 206,
#  'purposes': 207,
#  'algonquins': 208,
#  'cleavages': 209,
#  'merged': 210,
#  'stant': 211,
#  'azoo': 212,
#  'synthesis': 213,
#  'canvassing': 214,
#  'sluggish': 215,
#  'nowadays': 216,
#  'calk': 217,
#  'soapstone': 218,
#  'flagons': 219,
#  'offsome': 220,
#  'cavities': 221,
#  'alackaday': 222,
#  'rise': 223,
#  'goand': 224,
#  'waylaying': 225,
#  'thrusts': 226,
#  'notoriously': 227,
#  'dashes': 228,
#  'italian': 229,
#  'skittish': 230,
#  'austerely': 231,
#  'armload': 232,
#  'thesetting': 233,
#  'spiraling': 234,
#  'wesley': 235,
#  'peer': 236,
#  'screwball': 237,
#  'brick': 238,
#  'arclights': 239,
#  'ravages': 240,
#  'speculated': 241,
#  'groundnut': 242,
#  'hon': 243,
#  'recoiled': 244,
#  'salvage': 245,
#  'jobless': 246,
#  'dodges': 247,
#  'lawrenceville': 248,
#  'switched': 249,
#  'himmad': 250,
#  'sewn': 251,
#  'liners': 252,
#  'latter': 253,
#  'pepsin': 254,
#  'limousine': 255,
#  'backwardsto': 256,
#  'stem': 257,
#  'selectiveness': 258,
#  'hemorrhage': 259,
#  'fiancee': 260,
#  'waslooking': 261,
#  'magnificent': 262,
#  'thelistless': 263,
#  'cellar': 264,
#  'coexisted': 265,
#  'ofsome': 266,
#  'manglings': 267,
#  'fortnight': 268,
#  'gummy': 269,
#  'hope': 270,
#  'publication': 271,
#  'werejiggled': 272,
#  'leningrad': 273,
#  'wayof': 274,
#  'successor': 275,
#  'chaufroix': 276,
#  'default': 277,
#  'cochineal': 278,
#  'incredulously': 279,
#  'diewhile': 280,
#  'homeon': 281,
#  'rebut': 282,
#  'reeds': 283,
#  'ringlets': 284,
#  'thesawdust': 285,
#  'wriggled': 286,
#  'chargeyou': 287,
#  'wendy': 288,
#  'beforedresden': 289,
#  'andgo': 290,
#  'lenin': 291,
#  'pasthad': 292,
#  'tropical': 293,
#  'clarissemcclellan': 294,
#  'id': 295,
#  'finality': 296,
#  'rivalry': 297,
#  'germanswere': 298,
#  'nothingin': 299,
#  'presenting': 300,
#  'prints': 301,
#  'turnedpage': 302,
#  'hintand': 303,
#  'boston': 304,
#  'disenthrall': 305,
#  'fiat': 306,
#  'intersect': 307,
#  'furrin': 308,
#  'grainy': 309,
#  'hey': 310,
#  'freighter': 311,
#  'voyagers': 312,
#  'rods': 313,
#  'traction': 314,
#  'scared': 315,
#  'weirdly': 316,
#  'cycle': 317,
#  'glassy': 318,
#  'dressmaker': 319,
#  'moonless': 320,
#  'dilate': 321,
#  'move': 322,
#  'packin': 323,
#  'boldest': 324,
#  'appositeness': 325,
#  'roam': 326,
#  'astounding': 327,
#  'flashes': 328,
#  'national': 329,
#  'assassin': 330,
#  'sweatto': 331,
#  'andthis': 332,
#  'stalk': 333,
#  'revoir': 334,
#  'brawling': 335,
#  'corinne': 336,
#  'murmured': 337,
#  'silkolene': 338,
#  'repeating': 339,
#  'fussy': 340,
#  'grudge': 341,
#  'everyday': 342,
#  'intimately': 343,
#  'americacontents': 344,
#  'potful': 345,
#  'reclining': 346,
#  'xix': 347,
#  'collaredvest': 348,
#  'organization': 349,
#  'julybegan': 350,
#  'imported': 351,
#  'religiosity': 352,
#  'swaddled': 353,
#  'intenser': 354,
#  'maude': 355,
#  'thoseprosperous': 356,
#  'theamerican': 357,
#  'poland': 358,
#  'thefire': 359,
#  'kidnappers': 360,
#  'duplicate': 361,
#  'couldtalk': 362,
#  'overwork': 363,
#  'usually': 364,
#  'servility': 365,
#  'famines': 366,
#  'andsavage': 367,
#  'sznapsas': 368,
#  'stupid': 369,
#  'juries': 370,
#  'thesuff': 371,
#  'submergences': 372,
#  'phthia': 373,
#  'socialist': 374,
#  'ottomans': 375,
#  'pickpockets': 376,
#  'invalid': 377,
#  'discords': 378,
#  'areredistributing': 379,
#  'theywouldn': 380,
#  'hisbayonet': 381,
#  'prehistorical': 382,
#  'thewagons': 383,
#  'lovemaking': 384,
#  'notquite': 385,
#  'inanother': 386,
#  'fetter': 387,
#  'emptyand': 388,
#  'subterfuges': 389,
#  'arrest': 390,
#  'affable': 391,
#  'quarrels': 392,
#  'currency': 393,
#  'beheld': 394,
#  'integrity': 395,
#  'avenues': 396,
#  'ludicrously': 397,
#  'fudge': 398,
#  'underground': 399,
#  'thelivers': 400,
#  'mechanism': 401,
#  'amounts': 402,
#  'angleworm': 403,
#  'discipline': 404,
#  'nt': 405,
#  'fervor': 406,
#  'xviithe': 407,
#  'ancestors': 408,
#  'mycamp': 409,
#  'papery': 410,
#  'umpire': 411,
#  'meed': 412,
#  'eyeing': 413,
#  'hebulled': 414,
#  'incongruous': 415,
#  'recaptured': 416,
#  'ovationfrom': 417,
#  'verytime': 418,
#  'outfront': 419,
#  'her': 420,
#  'dank': 421,
#  'pauper': 422,
#  'yielded': 423,
#  'gloated': 424,
#  'ithe': 425,
#  'vastness': 426,
#  'gilded': 427,
#  'provides': 428,
#  'bitches': 429,
#  'plustraveling': 430,
#  'streetcar': 431,
#  'suddenly': 432,
#  'crucifixes': 433,
#  'reporting': 434,
#  'ai': 435,
#  'shudders': 436,
#  'shoe': 437,
#  'artful': 438,
#  'finishing': 439,
#  'bonnie': 440,
#  'unbosom': 441,
#  'headway': 442,
#  'joad': 443,
#  'surfeit': 444,
#  'gownand': 445,
#  'ferryboatstart': 446,
#  'louder': 447,
#  'stickersabout': 448,
#  'clouds': 449,
#  'robert': 450,
#  'spareness': 451,
#  'blanched': 452,
#  'readjustment': 453,
#  'atlast': 454,
#  'accuse': 455,
#  'andcome': 456,
#  'sa': 457,
#  'knights': 458,
#  'lv': 459,
#  'suite': 460,
#  'crusades': 461,
#  'scrapbook': 462,
#  'fellback': 463,
#  'themlearns': 464,
#  'polishes': 465,
#  'theflapping': 466,
#  'oldpots': 467,
#  'ck': 468,
#  'surpasses': 469,
#  'overestimating': 470,
#  'stationed': 471,
#  'twosides': 472,
#  'bolder': 473,
#  'knowles': 474,
#  'harrowing': 475,
#  'chivin': 476,
#  'progress': 477,
#  'sweethearts': 478,
#  'accursed': 479,
#  'camouflaged': 480,
#  'theones': 481,
#  'receded': 482,
#  'particular': 483,
#  'belated': 484,
#  'shavings': 485,
#  'vain': 486,
#  'trivialness': 487,
#  'turner': 488,
#  'perceptible': 489,
#  'xxxix': 490,
#  'blamedif': 491,
#  'reading': 492,
#  'formidable': 493,
#  'marriages': 494,
#  'alexander': 495,
#  'snapshots': 496,
#  'accounted': 497,
#  'pinioned': 498,
#  'weturned': 499,
#  'scaredmost': 500,
#  'coming': 501,
#  'nephew': 502,
#  'macey': 503,
#  'justifiedthrough': 504,
#  'february': 505,
#  'trots': 506,
#  'fourtimes': 507,
#  'indistinguishably': 508,
#  'shallows': 509,
#  'chaises': 510,
#  'teno': 511,
#  'drunks': 512,
#  'prelude': 513,
#  'expropriate': 514,
#  'thorpe': 515,
#  'hart': 516,
#  'pawnbroker': 517,
#  'khaki': 518,
#  'pressures': 519,
#  'becuz': 520,
#  'untaught': 521,
#  'stumps': 522,
#  'scrupulous': 523,
#  'fairrosamun': 524,
#  'arrows': 525,
#  'dipping': 526,
#  'loftus': 527,
#  'harvard': 528,
#  'corseting': 529,
#  'surroundin': 530,
#  'muses': 531,
#  'thurt': 532,
#  'pasturing': 533,
#  'sharper': 534,
#  'easiest': 535,
#  'rustle': 536,
#  'tiptop': 537,
#  'buzzy': 538,
#  'imbibe': 539,
#  'giggles': 540,
#  'salty': 541,
#  'customary': 542,
#  'whirlpools': 543,
#  'congealed': 544,
#  'furnace': 545,
#  'heknew': 546,
#  'boundaries': 547,
#  'mainspring': 548,
#  'dis': 549,
#  'oilily': 550,
#  'namely': 551,
#  'unfathomable': 552,
#  'bittern': 553,
#  'grievously': 554,
#  'omnipotent': 555,
#  'overcoat': 556,
#  'hose': 557,
#  'approved': 558,
#  'vein': 559,
#  'faiththat': 560,
#  'sensuous': 561,
#  'gaze': 562,
#  'antagonisms': 563,
#  'gl': 564,
#  'gravitate': 565,
#  'bf': 566,
#  'attested': 567,
#  'lubricating': 568,
#  'pinnacle': 569,
#  'expedients': 570,
#  'shperrits': 571,
#  'truculent': 572,
#  'hestarted': 573,
#  'ajuice': 574,
#  'imparted': 575,
#  'strawbries': 576,
#  'inviolate': 577,
#  'amissfor': 578,
#  'suddenpeacefulness': 579,
#  'onlywhether': 580,
#  'denounce': 581,
#  'judged': 582,
#  'confiding': 583,
#  'yap': 584,
#  'thatwhich': 585,
#  'ailments': 586,
#  'yearnings': 587,
#  'gaugehow': 588,
#  'divinedare': 589,
#  'roumanians': 590,
#  'truly': 591,
#  'seal': 592,
#  'pamphlet': 593,
#  'brahma': 594,
#  'tomy': 595,
#  'dwarfed': 596,
#  'convincingly': 597,
#  'lassitude': 598,
#  'flatcars': 599,
#  'tubs': 600,
#  'debonairly': 601,
#  'fumed': 602,
#  'bywhat': 603,
#  'welly': 604,
#  'feigning': 605,
#  'culpabler': 606,
#  'seymour': 607,
#  'economized': 608,
#  'yarded': 609,
#  'hischildhood': 610,
#  'riveron': 611,
#  'swaying': 612,
#  'chances': 613,
#  'rebelled': 614,
#  'coolly': 615,
#  'cub': 616,
#  'graveside': 617,
#  'verbatim': 618,
#  'trickery': 619,
#  'endowing': 620,
#  'unbroke': 621,
#  'dikes': 622,
#  'inexpressibly': 623,
#  'aproblem': 624,
#  'deceptions': 625,
#  'serge': 626,
#  'wheezed': 627,
#  'statements': 628,
#  'violence': 629,
#  'principal': 630,
#  'xvi': 631,
#  'ambition': 632,
#  'februarythirteenth': 633,
#  'hogshead': 634,
#  'jocoser': 635,
#  'multiplied': 636,
#  'onlylook': 637,
#  'worth': 638,
#  'lenient': 639,
#  'unacknowledged': 640,
#  'wildorado': 641,
#  'forced': 642,
#  'dictionaryresume': 643,
#  'haters': 644,
#  'themselves': 645,
#  'museums': 646,
#  'investigators': 647,
#  'concepts': 648,
#  'seta': 649,
#  'nutpresents': 650,
#  'superadded': 651,
#  'unsavory': 652,
#  'lakes': 653,
#  'connote': 654,
#  'explain': 655,
#  'reappearing': 656,
#  'ceil': 657,
#  'tactful': 658,
#  'seraphic': 659,
#  'ordained': 660,
#  'boltons': 661,
#  'spread': 662,
#  'repression': 663,
#  'quay': 664,
#  'famethat': 665,
#  'cracks': 666,
#  'inaudible': 667,
#  'himbusy': 668,
#  'lout': 669,
#  'rib': 670,
#  'shriven': 671,
#  'morality': 672,
#  'impetus': 673,
#  'pityingly': 674,
#  'unacceptable': 675,
#  'nylonbrushed': 676,
#  'philanthropic': 677,
#  'enclosure': 678,
#  'hefound': 679,
#  'oneof': 680,
#  'maturer': 681,
#  'createof': 682,
#  'rollin': 683,
#  'twistings': 684,
#  'loiters': 685,
#  'henderson': 686,
#  'pulpy': 687,
#  'menwas': 688,
#  'elastic': 689,
#  'supremacy': 690,
#  'thinks': 691,
#  'intrusted': 692,
#  'unmercifully': 693,
#  'cadence': 694,
#  'whitewhiskers': 695,
#  'replenishing': 696,
#  'mewithout': 697,
#  'sheexplained': 698,
#  'lacked': 699,
#  'sighed': 700,
#  'makers': 701,
#  'hir': 702,
#  'contemporaneous': 703,
#  'washers': 704,
#  'sifting': 705,
#  'leeds': 706,
#  'zipping': 707,
#  'hugely': 708,
#  'skidded': 709,
#  'hifalut': 710,
#  'pretenses': 711,
#  'hosmer': 712,
#  'proprietary': 713,
#  'heads': 714,
#  'whitefolks': 715,
#  'handsomepassage': 716,
#  'praetorian': 717,
#  'withother': 718,
#  'infrequently': 719,
#  'olaus': 720,
#  'browbeaten': 721,
#  'unbuttoned': 722,
#  'irretrievable': 723,
#  'elaborate': 724,
#  'inparticular': 725,
#  'lentils': 726,
#  'marveled': 727,
#  'broadshoulders': 728,
#  'dismounted': 729,
#  'sanction': 730,
#  'triangular': 731,
#  'demanding': 732,
#  'magicfingers': 733,
#  'appointing': 734,
#  'dusts': 735,
#  'recover': 736,
#  'oblivious': 737,
#  'wanderin': 738,
#  'buzzard': 739,
#  'roseto': 740,
#  'trowsers': 741,
#  'muscleswould': 742,
#  'scott': 743,
#  'laym': 744,
#  'defective': 745,
#  'laggards': 746,
#  'chile': 747,
#  'india': 748,
#  'gawkiness': 749,
#  'canteen': 750,
#  'jesting': 751,
#  'ark': 752,
#  'convicts': 753,
#  'sepa': 754,
#  'ings': 755,
#  'complaints': 756,
#  'snubs': 757,
#  'despatched': 758,
#  'waterrunning': 759,
#  'gobble': 760,
#  'wealthiest': 761,
#  'grumblers': 762,
#  'repudiated': 763,
#  'irreproachable': 764,
#  'newsstands': 765,
#  'analogy': 766,
#  'ofgrinding': 767,
#  'pretexts': 768,
#  'unformed': 769,
#  'thecosmetics': 770,
#  'etat': 771,
#  'too': 772,
#  'withmanly': 773,
#  'knees': 774,
#  'angle': 775,
#  'thoughtabout': 776,
#  'exert': 777,
#  'conspiracy': 778,
#  'paints': 779,
#  'kamskatka': 780,
#  'disgust': 781,
#  'incentive': 782,
#  'sub': 783,
#  'houn': 784,
#  'chimneypiece': 785,
#  'ants': 786,
#  'obliquely': 787,
#  'oblivion': 788,
#  'sion': 789,
#  'insectdeath': 790,
#  'makinga': 791,
#  'klatches': 792,
#  'adaptations': 793,
#  'boot': 794,
#  'integrate': 795,
#  'clementine': 796,
#  'omnifold': 797,
#  'vise': 798,
#  'lie': 799,
#  'enit': 800,
#  'danagger': 801,
#  'ssoliloquy': 802,
#  'didst': 803,
#  'andthen': 804,
#  'sombrero': 805,
#  'anxieties': 806,
#  'advance': 807,
#  'blacklisted': 808,
#  'secondhand': 809,
#  'closetand': 810,
#  'entrancing': 811,
#  'emergency': 812,
#  'cabinets': 813,
#  'andshe': 814,
#  'chucked': 815,
#  'commitment': 816,
#  'chasing': 817,
#  'timescan': 818,
#  'listennice': 819,
#  'amethyst': 820,
#  'urine': 821,
#  'bo': 822,
#  'chewy': 823,
#  'furahead': 824,
#  'wistfully': 825,
#  'hmmmm': 826,
#  'starting': 827,
#  'judges': 828,
#  'appurtenances': 829,
#  'satisfy': 830,
#  'lousiest': 831,
#  'compose': 832,
#  'keg': 833,
#  'bluish': 834,
#  'wiles': 835,
#  'bookthere': 836,
#  'dimes': 837,
#  'challengingly': 838,
#  'afeard': 839,
#  'lltake': 840,
#  'catapult': 841,
#  'bestowed': 842,
#  'lillian': 843,
#  'agrarian': 844,
#  'risky': 845,
#  'police': 846,
#  'solitude': 847,
#  'ifi': 848,
#  'treasure': 849,
#  'limerick': 850,
#  'thingswe': 851,
#  'afford': 852,
#  'swung': 853,
#  'noiselessly': 854,
#  'yellowstone': 855,
#  'theheat': 856,
#  'bybeginning': 857,
#  'large': 858,
#  'warmblasts': 859,
#  'looard': 860,
#  'letanybody': 861,
#  'storms': 862,
#  'allold': 863,
#  'sonnets': 864,
#  'lattice': 865,
#  'tug': 866,
#  'daywandering': 867,
#  'indefinite': 868,
#  'notcoming': 869,
#  'enrage': 870,
#  'filipinos': 871,
#  'skunk': 872,
#  'frombreslau': 873,
#  'bridgewater': 874,
#  'outwhat': 875,
#  'comf': 876,
#  'ler': 877,
#  'hishand': 878,
#  'acute': 879,
#  'damrell': 880,
#  'winnowing': 881,
#  'tnd': 882,
#  'griffe': 883,
#  'insult': 884,
#  'otherpeople': 885,
#  'savor': 886,
#  'creek': 887,
#  'destructive': 888,
#  'actual': 889,
#  'blurred': 890,
#  'rutlier': 891,
#  'besttime': 892,
#  'indelicacy': 893,
#  'intelligent': 894,
#  'belligerence': 895,
#  'coarser': 896,
#  'asplain': 897,
#  'ascontract': 898,
#  'lessthan': 899,
#  'checotah': 900,
#  'deathis': 901,
#  'disestablished': 902,
#  'rig': 903,
#  'jailed': 904,
#  'rationality': 905,
#  'fixedly': 906,
#  'hymie': 907,
#  'andscratching': 908,
#  'wentdown': 909,
#  'politely': 910,
#  'arhymeless': 911,
#  'leaning': 912,
#  'sported': 913,
#  'amberwith': 914,
#  'willbe': 915,
#  'pronounce': 916,
#  'social': 917,
#  'all': 918,
#  'housecleaning': 919,
#  'sumptuously': 920,
#  'twlcet': 921,
#  'elephantine': 922,
#  'td': 923,
#  'darn': 924,
#  'vouldn': 925,
#  'hordes': 926,
#  'hoop': 927,
#  'consciously': 928,
#  'keroseneand': 929,
#  'wasobleeged': 930,
#  'sopeople': 931,
#  'annuder': 932,
#  'phelpses': 933,
#  'surer': 934,
#  'therewarn': 935,
#  'cleans': 936,
#  'toughness': 937,
#  'lodgings': 938,
#  'grew': 939,
#  'slowlythe': 940,
#  'shapelessness': 941,
#  'paymaster': 942,
#  'dumbmessages': 943,
#  'achilles': 944,
#  'shepherds': 945,
#  'peering': 946,
#  'individualize': 947,
#  'passelof': 948,
#  'justenough': 949,
#  'michigan': 950,
#  'marshy': 951,
#  'erudition': 952,
#  'withanother': 953,
#  'elves': 954,
#  'sheltering': 955,
#  'bombing': 956,
#  'cathedrals': 957,
#  'bordering': 958,
#  'mediocrities': 959,
#  'signit': 960,
#  'apparently': 961,
#  'leipzig': 962,
#  'laurence': 963,
#  'heruncles': 964,
#  'television': 965,
#  'warfare': 966,
#  'cemetery': 967,
#  'scuffle': 968,
#  'ejaculates': 969,
#  'xliv': 970,
#  'undiscriminating': 971,
#  'anderson': 972,
#  'fad': 973,
#  'cloy': 974,
#  'columns': 975,
#  'ir': 976,
#  'thelist': 977,
#  'payer': 978,
#  'brawlers': 979,
#  'maelstrom': 980,
#  'absolute': 981,
#  'dows': 982,
#  'fixed': 983,
#  'mistakes': 984,
#  'dauphine': 985,
#  'hadstolen': 986,
#  'wassticking': 987,
#  'thegreasy': 988,
#  'alibi': 989,
#  'overand': 990,
#  'poinsettias': 991,
#  'tethered': 992,
#  'uninflected': 993,
#  'miles': 994,
#  'complexions': 995,
#  'harming': 996,
#  'camphor': 997,
#  'knowhow': 998,
#  'urns': 999,
#  'cimeter': 1000,
#  ...}

# %%
data_ok = data.text.apply(lambda x: [word_index.get(word, 0) for word in x])
len(data_ok.iloc[2])
# Out:
# 37434

# %%
maxlen = max(len(x) for x in data_ok)
maxlen
# Out:
# 667033

# %%
data_ok = tf.keras.preprocessing.sequence.pad_sequences(data_ok.values, maxlen=maxlen)

# %%
data_ok.shape
# Out:
# (15, 667033)

# %%
data.label.values
# Out:
# array([4.33, 4.17, 4.01, 3.99, 4.04, 3.84, 4.03, 3.54, 4.13, 3.62, 3.68,
#        3.92, 3.75, 3.66, 3.83])

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
def train_model():
    model = keras.Sequential()
    model.add(layers.Embedding(max_word, 16, input_length=maxlen))
    model.add(layers.Bidirectional(layers.LSTM(64,
                         dropout=0.2,
                         recurrent_dropout=0.5)))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer=keras.optimizers.RMSprop(),
              loss='binary_crossentropy',
              metrics=['acc'])
    return model

# %%
model = train_model()

# %%
learning_rate_reduction = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.3, min_lr=0.00001)

# %%
history = model.fit(data_ok, 
                     data.label.values, 
                     epochs=30, 
                     batch_size=128, 
                     validation_split=0.2,
                     callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/30
# 1/1 [==============================] - 0s 216ms/step - loss: 0.7035 - acc: 0.3333 - val_loss: 0.5172 - val_acc: 0.0000e+00
# Epoch 2/30
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6239 - acc: 0.3333 - val_loss: 0.3661 - val_acc: 0.0000e+00
# Epoch 3/30
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5775 - acc: 0.3333 - val_loss: 0.2221 - val_acc: 0.0000e+00
# Epoch 4/30
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5099 - acc: 0.3333 - val_loss: 0.0458 - val_acc: 0.0000e+00
# Epoch 5/30
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4396 - acc: 0.3333 - val_loss: -0.1791 - val_acc: 0.0000e+00
# Epoch 6/30
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3499 - acc: 0.3333 - val_loss: -0.4743 - val_acc: 0.0000e+00
# Epoch 7/30
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2064 - acc: 0.3333 - val_loss: -0.8681 - val_acc: 0.0000e+00
# Epoch 8/30
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1079 - acc: 0.3333 - val_loss: -1.3679 - val_acc: 0.0000e+00
# Epoch 9/30
# 1/1 [==============================] - 0s 8ms/step - loss: -0.2524 - acc: 0.3333 - val_loss: -2.1527 - val_acc: 0.0000e+00
# Epoch 10/30
# 1/1 [==============================] - 0s 8ms/step - loss: -0.2685 - acc: 0.3333 - val_loss: -3.0576 - val_acc: 0.0000e+00
# Epoch 11/30
# 1/1 [==============================] - 0s 8ms/step - loss: -0.8921 - acc: 0.3333 - val_loss: -4.6252 - val_acc: 0.0000e+00
# Epoch 12/30
# 1/1 [==============================] - 0s 9ms/step - loss: -1.2364 - acc: 0.3333 - val_loss: -6.7606 - val_acc: 0.0000e+00
# Epoch 13/30
# 1/1 [==============================] - 0s 8ms/step - loss: -2.0237 - acc: 0.3333 - val_loss: -9.9062 - val_acc: 0.0000e+00
# Epoch 14/30
# 1/1 [==============================] - 0s 8ms/step - loss: -2.8463 - acc: 0.3333 - val_loss: -14.1916 - val_acc: 0.0000e+00
# Epoch 15/30
# 1/1 [==============================] - 0s 9ms/step - loss: -4.7493 - acc: 0.3333 - val_loss: -19.3228 - val_acc: 0.0000e+00
# Epoch 16/30
# 1/1 [==============================] - 0s 8ms/step - loss: -6.8371 - acc: 0.3333 - val_loss: -24.2707 - val_acc: 0.0000e+00
# Epoch 17/30
# 1/1 [==============================] - 0s 8ms/step - loss: -7.8724 - acc: 0.3333 - val_loss: -27.9643 - val_acc: 0.0000e+00
# Epoch 18/30
# 1/1 [==============================] - 0s 9ms/step - loss: -8.5373 - acc: 0.3333 - val_loss: -30.5407 - val_acc: 0.0000e+00
# Epoch 19/30
# 1/1 [==============================] - 0s 9ms/step - loss: -8.9800 - acc: 0.3333 - val_loss: -32.5093 - val_acc: 0.0000e+00
# Epoch 20/30
# 1/1 [==============================] - 0s 8ms/step - loss: -9.9855 - acc: 0.3333 - val_loss: -34.2370 - val_acc: 0.0000e+00
# Epoch 21/30
# 1/1 [==============================] - 0s 8ms/step - loss: -12.1931 - acc: 0.3333 - val_loss: -35.7448 - val_acc: 0.0000e+00
# Epoch 22/30
# 1/1 [==============================] - 0s 8ms/step - loss: -13.1045 - acc: 0.3333 - val_loss: -37.0110 - val_acc: 0.0000e+00
# Epoch 23/30
# 1/1 [==============================] - 0s 8ms/step - loss: -12.8324 - acc: 0.3333 - val_loss: -38.0070 - val_acc: 0.0000e+00
# Epoch 24/30
# 1/1 [==============================] - 0s 9ms/step - loss: -12.6254 - acc: 0.3333 - val_loss: -38.9478 - val_acc: 0.0000e+00
# Epoch 25/30
# 1/1 [==============================] - 0s 8ms/step - loss: -13.2951 - acc: 0.3333 - val_loss: -39.7995 - val_acc: 0.0000e+00
# Epoch 26/30
# 1/1 [==============================] - 0s 8ms/step - loss: -13.1433 - acc: 0.3333 - val_loss: -40.5310 - val_acc: 0.0000e+00
# Epoch 27/30
# 1/1 [==============================] - 0s 8ms/step - loss: -12.7043 - acc: 0.3333 - val_loss: -41.2470 - val_acc: 0.0000e+00
# Epoch 28/30
# 1/1 [==============================] - 0s 9ms/step - loss: -13.2109 - acc: 0.3333 - val_loss: -41.9032 - val_acc: 0.0000e+00
# Epoch 29/30
# 1/1 [==============================] - 0s 8ms/step - loss: -14.8142 - acc: 0.3333 - val_loss: -42.6089 - val_acc: 0.0000e+00
# Epoch 30/30
# 1/1 [==============================] - 0s 8ms/step - loss: -13.5834 - acc: 0.3333 - val_loss: -43.2270 - val_acc: 0.0000e+00

# %%
model.save('model/model1.keras')

# %%
model = keras.models.load_model('model/model1.keras')
model.predict(data_ok)
# Out:
# array([[0.99999946],
#        [0.9999995 ],
#        [0.9999995 ],
#        [0.9999994 ]], dtype=float32)
